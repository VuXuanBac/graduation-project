# %%
from plotter import *

# %%
path = "../simulation/generate/0505-summary/main.csv"
data = pd.read_csv(path)

CompetitiveKey = "BP2"
SelfishKey = "BS2"

# %%
BINS = 50

# %%
goodP = data[data["Dpe"] > 20]
ecdfs(
    data=goodP,
    columns=["NCP.RL", "BS2.RLP", "BP2.RLP"],
    labels=["NC", "SF", "CP"]
)

# %%
goodgoodP = goodP[goodP["Dpe"] > goodP["Dse"]]
print(len(goodgoodP))
ecdfs(
    data=goodgoodP,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 55480

# %%
bad1 = data[data["Dpe"] <= 15]
print(len(bad1))
ecdfs(
    data=bad1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 99760

# %%
badgood1 = bad1[bad1["Dpe"] >= bad1["Dse"]]
print(len(badgood1))
ecdfs(
    data=badgood1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 25020

# %%
badbad1 = bad1[bad1["Dpe"] <= bad1["Dse"]]
print(len(badbad1))
ecdfs(
    data=badbad1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 74740

# %%
good1 = data[data["Dpe"] >= 15]
goodgood1 = good1[good1["Dpe"] >= good1["Dse"]]
print(len(goodgood1))
ecdfs(
    data=goodgood1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 74975

# %%
goodbad1 = good1[good1["Dpe"] <= good1["Dse"]]
print(len(goodbad1))
ecdfs(
    data=goodbad1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 25265

# %%
badgood1 = data[data["Dpe"] >= data["Dse"]]
print(len(badgood1))
ecdfs(
    data=badgood1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
badgood1[["BP2.RLP", "NCP.RL", "BS2.RLP"]].describe()
# Out:
# 99995
#             BP2.RLP        NCP.RL       BS2.RLP
# count  9.999500e+04  9.999500e+04  99995.000000
# mean   8.646864e-02  2.270830e-01      0.229934
# std    1.624752e-01  2.798898e-01      0.258525
# min   -9.556927e-33  0.000000e+00      0.000000
# 25%    1.117771e-08  1.886195e-12      0.001309
# 50%    2.064210e-03  4.967089e-02      0.104002
# 75%    8.730150e-02  4.561693e-01      0.445563
# max    7.993390e-01  8.000000e-01      0.799998

# %%
badgood1.hist(["NCP.RL", "BS2.RLP"])
# Out:
# array([[<Axes: title={'center': 'NCP.RL'}>,
#         <Axes: title={'center': 'BS2.RLP'}>]], dtype=object)

# %%
badgood1 = data[data["Dpe"] <= data["Dse"] - 5]
print(len(badgood1))
ecdfs(
    data=badgood1,
    columns=["BP2.RLP", "NCP.RL", "BS2.RLP"],
    labels=[r"$\text{CP}$", r"$\text{NC}$", r"$\text{SF}$"],
    xlabel=r"$R_L^{(P)}$",
    xlim=None,
)
# Out:
# 69460

# %%
D2 = badgood1["NCP.RL"] - badgood1[f"{CompetitiveKey}.RLP"]
draw(
    D2, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap}$",
    ylabel=r"$\text{Empirical CDF}$",
    # xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    25020.000000
# mean         0.321715
# std          0.302297
# min         -0.754963
# 25%          0.000358
# 50%          0.304020
# 75%          0.618104
# max          0.799981
# dtype: float64
# min: -0.8, max: 0.8, bins: [-0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25
#  -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35
#   0.4   0.45  0.5   0.55  0.6   0.65  0.7   0.75]

# %%
D2 = badgood1["NCP.RL"] - badgood1[f"{SelfishKey}.RLP"]
draw(
    D2, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap}$",
    ylabel=r"$\text{Empirical CDF}$",
    # xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    25020.000000
# mean         0.130742
# std          0.352908
# min         -0.799317
# 25%         -0.013040
# 50%          0.026556
# 75%          0.386391
# max          0.799977
# dtype: float64
# min: -0.8, max: 0.8, bins: [-0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25
#  -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35
#   0.4   0.45  0.5   0.55  0.6   0.65  0.7   0.75]
# Error in callback <function flush_figures at 0x000001C87CE52EF0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File d:\Python Environment\Optimization\lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# ...

# %% [markdown]
# # Good Channel Condition

# %% [markdown]
# # Good 1: data["Dpe"] > 20

# %%
goodP = data[data["Dpe"] > 20]

# %%
goodP = data[data["Dpe"] > 20]
ecdfs(
    data=goodP,
    columns=["NCP.RL", "BS2.RLP", "BP2.RLP"],
    labels=["NC", "SF", "CP"]
)

# %%
# D1 = goodP["NCP.RL"]
# draw(
#     D1, bins_width=0.05, grid=False, cumulative=False, 
#     xlabel=r"$R_L^{(P)} - \text{NC}$",
#     ylabel=r"$\text{Empirical CDF}$",
#     xlim=[0, 0.7],
#     # ylim=[0.0, 1.0]
# )

# %%
# D3 = goodP[f"{CompetitiveKey}.RLP"]
# D3 =  D3[D3 >= 0]
# draw(
#     D3, bins_width=0.05, grid=False, cumulative=False, 
#     xlabel=r"$R_L^{(P)} - \text{CP}$",
#     ylabel=r"$\text{Empirical CDF}$",
#     xlim=[0, 0.8],
#     # ylim=[0.0, 1.0]
# )

# %%
D2 = goodP["NCP.RL"] - goodP[f"{CompetitiveKey}.RLP"]
draw(
    D2, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap}$",
    ylabel=r"$\text{Empirical CDF}$",
    # xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    66754.000000
# mean         0.042680
# std          0.137484
# min         -0.692498
# 25%         -0.000087
# 50%          0.000000
# 75%          0.025834
# max          0.664531
# dtype: float64
# min: -0.7, max: 0.7, bins: [-0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25 -0.2  -0.15
#  -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45
#   0.5   0.55  0.6   0.65]

# %% [markdown]
# # Good 2: Dpe > Dse + 5

# %%
goodP2 = data[data["Dpe"] > data["Dse"] + 10]
# goodS = data[data["Dsf"] > data["Dpf"]]

# %%
D4 = goodP2["NCP.RL"]
draw(
    D4, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} - \text{NC}$",
    ylabel=r"$\text{Empirical CDF}$",
    xlim=[0, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    4.455000e+04
# mean     1.589385e-01
# std      2.228130e-01
# min      0.000000e+00
# 25%      3.169397e-20
# 50%      1.090186e-02
# 75%      3.043906e-01
# max      7.843943e-01
# Name: NCP.RL, dtype: float64
# min: -0.1, max: 0.8, bins: [-0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45
#   0.5   0.55  0.6   0.65  0.7   0.75]

# %%
D15 = goodP2[f"{CompetitiveKey}.RLP"]
draw(
    D15, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} - \text{CP}$",
    ylabel=r"$\text{Empirical CDF}$",
    xlim=[0, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    4.455000e+04
# mean     3.069659e-02
# std      8.655158e-02
# min     -9.556927e-33
# 25%      3.099156e-12
# 50%      1.037940e-04
# 75%      1.044345e-02
# max      7.519395e-01
# Name: BP2.RLP, dtype: float64
# min: -0.1, max: 0.8, bins: [-0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45
#   0.5   0.55  0.6   0.65  0.7   0.75]

# %%
D5 = goodP2["NCP.RL"] - goodP2[f"{CompetitiveKey}.RLP"]
draw(
    D5, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap} - \text{CP}$",
    ylabel=r"$\text{Empirical CDF}$",
    xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    4.455000e+04
# mean     1.282419e-01
# std      2.067885e-01
# min     -6.522071e-01
# 25%     -3.334841e-78
# 50%      1.535609e-03
# 75%      2.163513e-01
# max      7.843927e-01
# dtype: float64
# min: -0.7, max: 0.8, bins: [-0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25 -0.2  -0.15
#  -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45
#   0.5   0.55  0.6   0.65  0.7   0.75]

# %%
D14 = goodP["NCP.RL"] - goodP[f"{SelfishKey}.RLP"]
draw(
    D14, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap} - \text{SF}$",
    ylabel=r"$\text{Empirical CDF}$",
    # xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    66754.000000
# mean        -0.086430
# std          0.226862
# min         -0.734493
# 25%         -0.167714
# 50%         -0.006598
# 75%          0.000000
# max          0.664502
# dtype: float64
# min: -0.8, max: 0.7, bins: [-0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25
#  -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35
#   0.4   0.45  0.5   0.55  0.6   0.65]

# %% [markdown]
# # Bad Channel Condition

# %% [markdown]
# # Bad 2: Dpe <= 10

# %%
badP2 = data[data["Dpe"] <= 15]

# %%
badP2.hist("Dpe", bins=100)
# Out:
# array([[<Axes: title={'center': 'Dpe'}>]], dtype=object)

# %%
D8 = badP2["NCP.RL"] - badP2[f"{CompetitiveKey}.RLP"]
draw(
    D8, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap} - \text{CP}$",
    ylabel=r"$\text{Empirical CDF}$",
    xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    99760.000000
# mean         0.095854
# std          0.237154
# min         -0.799683
# 25%         -0.000202
# 50%          0.000298
# 75%          0.109936
# max          0.799981
# dtype: float64
# min: -0.8, max: 0.8, bins: [-0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25
#  -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35
#   0.4   0.45  0.5   0.55  0.6   0.65  0.7   0.75]

# %%
D8 = badP2["NCP.RL"] - badP2[f"{SelfishKey}.RLP"]
draw(
    D8, bins_width=0.05, grid=False, cumulative=False, 
    xlabel=r"$R_L^{(P)} \text{Gap} - \text{SF}$",
    ylabel=r"$\text{Empirical CDF}$",
    xlim=[-0.8, 0.8],
    # ylim=[0.0, 1.0]
)
# Out:
# count    99760.000000
# mean        -0.059953
# std          0.303026
# min         -0.800000
# 25%         -0.082114
# 50%         -0.001030
# 75%          0.001320
# max          0.799977
# dtype: float64
# min: -0.8, max: 0.8, bins: [-0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25
#  -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35
#   0.4   0.45  0.5   0.55  0.6   0.65  0.7   0.75]
